# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushkaDwivedi17/datathon/blob/master/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("""                                  :::WELCOME TO INDIAN RAILWAY:::
                                           SAFETY | SECURITY | PUNCTUALITY
                                          
                                 Contact us      Ticket Booking       Food Service """)
 
    
print("\n")

import datetime
from datetime import date
d=date.today()
print("Date-"+d.strftime("%Y-%b-%d"))
print("Day-"+d.strftime("%A"))

from datetime import time
t=datetime.datetime.now()
t1=t.time()
print("Time-",t1)
print(" ")

fp=open("admin.txt","a+")
g="1234"

def fun4():
    global money
    if(classes.casefold()=="m" or classes.casefold()=="l" or classes.casefold()=="u"):
        if(foods.casefold()=="yes"):
            money=600
        else:
            money=500
    else:
        if(foods.casefold()=="yes"):
            money=300
        else:
            money=250

def fun1():
    global foods
    global classes
    global trnid
    initial=input("Enter Initial City: ")
    final=input("Enter Destination: ")
    print("Trains Found: ")
    print(initial,"to",final,"time = 18:15","train id=t1")
    print(initial,"to",final,"time = 22:00","train id=t2")
    yes=input("Press 1 for Ticket Booking : ")
    if yes=="1":
        trnid=input("Please Enter Train id: ")
        if trnid=="t1":
                name=input("Enter Your Name: ")
                age=input("Enter Your Age: ")
                classes=input("Enter L for Lower Sleeper,M for Middle Sleeper, U for Upper Sleeper,S for Seater : ")
                gender=input("Enter your Gender:F for Female, M for Male, T for Transgender: ")
                dateofbirth=input("Enter your Date of Birth in dd/mm/yy format: ")
                mobile=input("Enter Your Mobile No.  +91")
                foods=input("For Food Services enter yes else no: ") 
                fun4()
                print("Total amount to be paid is ",money)
                print("""Mode of Payment
                  1 For Debit card:
                  2 For Phone Pay: """)
                mop=int(input())
                
                if(mop==1):
                    print("Enter Card Details:")
                    cdhn=input("Enter card holder name : ")
                    cdno=int(input("Enter Card Number"))
                    cvv=int(input("Enter CVV Number : "))
                    exdt=input("Enter Expiry Date:  ")
                    otp=int(input("Enter 6 Digit OTP"))
                    print("Transaction Successful.")
                    print("Ticket Booked Successfully")
                    fp.seek(0,1)
                    fp.write(name+"          "+age+"          "+classes+"          "+gender+"          "+dateofbirth+"          "+mobile)
                    fp.write("\n")
                    fp.close()
                    fp1=open("BookedSeats","a+")
                    fp1.write("\n")
                    fp1.write("t1"+classes.upper())
                    fp1.write("\n")
                    fp1.close()
                    
                elif(mop==2):
                    print("Enter registered mobile number")
                    rm=input()
                    if(len(rm)!=10):
                        print("Invalid Mobile Number\nPlease Enter Again: ")
                        rmm=input()
                        if(len(rmm)!=10):
                            print("SORRY! Invalid Mobile Number ")
                            
                    else:        
                        upi=int(input("Enter 6 Digit UPI Number")) 
                        print("Transaction Successful.")    
                        print("Ticket Booked Successfully")
                        fp.seek(0,1)
                        fp.write(name+"          "+age+"          "+classes+"          "+gender+"          "+dateofbirth+"          "+mobile)
                        fp.write("\n")
                        fp.close()
                        fp1=open("BookedSeats","a+")
                        fp1.write("\n")
                        fp1.write("t1"+classes.upper())
                        fp1.write("\n")
                        fp1.close()
        elif trnid=="t2":
                name=input("Enter Your Name: ")
                age=input("Enter Your Age: ")
                classes=input("Enter L for Lower Sleeper,M for Middle Sleeper, U for Upper Sleeper,S for Seater : ")
                gender=input("Enter your Gender:F for Female, M for Male, T for Transgender: ")
                dateofbirth=input("Enter your Date of Birth in dd/mm/yy format:")
                mobile=input("Enter Your Mobile No.  +91")
                foods=input("For Food Services enter yes else no: ")
                print("\n")
                fun4()
                print("Total amount to be paid is ",money)
                print("""\nMode of Payment
                  1 For Debit card:
                  2 For Phone Pay: """)
                mop=int(input())
                
                if(mop==1):
                    print("Enter Card Details:")
                    cdhn=input("Enter card holder name : ")
                    cdno=int(input("Enter Card Number"))
                    cvv=int(input("Enter CVV Number : "))
                    exdt=input("Enter Expiry Date:  ")
                    otp=int(input("Enter 6 Digit OTP"))
                    print("Transaction Successful.")
                    print("Ticket Booked Successfully")
                    fp=open("admin.txt","a+")
                    fp.write(name+"          "+age+"          "+classes+"          "+gender+"          "+dateofbirth+"          "+mobile)
                    fp.write("\n")
                    fp.close()
                    fp1=open("BookedSeats","a+")
                    fp1.write("\n")
                    fp1.write("t2"+classes.upper())
                    fp1.write("\n")
                    fp1.close()
                    fp.close()
                    
                elif(mop==2):
                    print("Enter registered mobile number")
                    rm=input()
                    if(len(rm)!=10):
                        print("Invalid Mobile Number\nPlease Enter Again: ")
                        rmm=input()
                        if(len(rmm)!=10):
                            print("SORRY! Invalid Mobile Number ")
                            
                    else:        
                        upi=int(input("Enter 6 Digit UPI Number")) 
                        print("Transaction Successful.")    
                        print("Ticket Booked Successfully")
                        fp=open("admin.txt","a+")
                        fp.write(name+"          "+age+"          "+classes+"          "+gender+"          "+dateofbirth+"          "+mobile)
                        fp.write("\n")
                        fp.close()
                        fp1=open("BookedSeats","a+")
                        fp1.write("\n")
                        fp1.write("t2"+classes.upper())
                        fp1.write("\n")
                        fp1.close()
                        fp.close()
def fun2():
    adminpw=input("Enter Password: ")
    
    if g==adminpw:
        view=int(input("Press 1 for View the Details Of Passengers:\nPress 2 for View Booked Seats:\nPress 3 to Read feedback "))
        if view==1:
            fp=open("admin.txt","a+")
            fp.seek(0,0)
            print(fp.read())
        if view==2:
            fun5()
            
            print("Enter train id: t1,t2:")
            fp1=open("BookedSeats","r")
            trainid=input()
            if trainid=="t1":
                print("Here is the Required List:")
                print("NUMBER OF LOWER SLEEPER OCCUPIED IS ",c1)
                print("NUMBER OF MIDDLE SLEEPER OCCUPIED IS ",c2)
                print("NUMBER OF UPPER SLEEPER OCCUPIED IS ",c3)
                print("NUMBER OF SEATER OCCUPIED IS ",c4)
                
            elif trainid=="t2":   
                print("Here is the Required List:")
                print("NUMBER OF LOWER SLEEPER OCCUPIED IS ",c5)
                print("NUMBER OF MIDDLE SLEEPER OCCUPIED IS ",c6)
                print("NUMBER OF UPPER SLEEPER OCCUPIED IS ",c7)
                print("NUMBER OF SEATER OCCUPIED IS ",c8)
                
        if view==3:
            fp3=open("feedback","r")
            print(fp3.read())
            fp3.close()
            
    else:
        print("Wrong Password")
def fun3():
    print("Welcome to INDIAN RAILWAYS Customer Services\n")
    print("press 1 for contact details and press 2 for Leaving feedback and Press 3 for Reading Previous Feedback")
    c=int(input())
    if c==1:
        print("contact no.- 99-4555\nemail address- railway@india.com")
    if c==2:
        fp3=open("feedback","a+")
        print("Enter your name")
        string=input()
        str=input("Leave Your Feedback Here : ")
        fp3.write(string)
        fp3.write("-")
        fp3.write(str)
        fp3.write("\n")
        print("Thank You")
        fp3.close()
    if c==3:
        fp3=open("feedback","r")
        print(fp3.read())
        fp3.close()
        
def fun5():        
        fp1=open("BookedSeats","r")
        global c1
        global c2
        global c3
        global c4
        global c5
        global c6
        global c7
        global c8
        c1=0
        c2=0
        c3=0
        c4=0
        c5=0        
        c6=0
        c7=0
        c8=0
        for i in fp1:
                u=str(i[2])
                if(str(i[1])=="1" and u=="L"):
                    c1+=1
                elif(str(i[1])=="1" and u=="M"):
                    c2+=1
                elif(str(i[1])=="1" and u=="U"):
                    c3+=1 
                elif(str(i[1])=="1" and u=="S"):
                    c4+=1
                elif(str(i[1])=="2" and u=="L"):
                    c5+=1
                elif(str(i[1])=="2" and u=="M"):
                    c6+=1
                elif(str(i[1])=="2" and u=="U"):
                    c7+=1    
                elif(str(i[1])=="2" and u=="S"):
                    c8+=1 
                

                
                
print("Press 1 for Ticket Booking:\nPress 2 for Admin Login press:\nPress 3 for customer services: ")
s=int(input())

if s==1:
    fun1()

if s==2:
    fun2()

if s==3:
    fun3()

    
if s==4:
    print("Invalid Number")
# Out:
#                                   :::WELCOME TO INDIAN RAILWAY:::
#                                            SAFETY | SECURITY | PUNCTUALITY
#
#                                  Contact us      Ticket Booking       Food Service
#
#
# Date-2020-Sep-23
# Day-Wednesday
# Time- 01:51:17.504591
#
# Press 1 for Ticket Booking:
# Press 2 for Admin Login press:
# Press 3 for customer services:
# 3
# Welcome to INDIAN RAILWAYS Customer Services
#
# press 1 for contact details and press 2 for Leaving feedback and Press 3 for Reading Previous Feedback
# 1
# contact no.- 99-4555
# email address- railway@india.com
